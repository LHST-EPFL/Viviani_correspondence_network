# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#uploading the filtred database
filtred_db = pd.read_csv('filtred.csv')
filtred_db
# Out:
#                          Expéditeur  \
# 0      Viviani  Vincenzo  1622-1703
# 1      Viviani  Vincenzo  1622-1703
# 2      Viviani  Vincenzo  1622-1703
# 3      Viviani  Vincenzo  1622-1703
# 4      Viviani  Vincenzo  1622-1703
# ...                             ...
# 2869   Viviani  Vincenzo  1622-1703
# 2870  Magalotti  Lorenzo  1637-1712
# 2871     Steensen  Niels  1638-1686
# 2872   Viviani  Vincenzo  1622-1703
# 2873   Viviani  Vincenzo  1622-1703
#
#                                                   Notes  \
# 0     Tipologia: letteraIncipit: "Come posso non agg...
# 1     Tipologia: letteraIncipit: "Reputo a mio gran ...
# 2     Tipologia: letteraIncipit: "L'esser io per spa...
# 3     Tipologia: letteraIncipit: "Haverei necessità ...
# 4     Tipologia: letteraIncipit: "Qui tutto giorno c...
# ...                                                 ...
# 2869  Tipologia: letteraIncipit: "Così cadano dal Ci...
# 2870  Tipologia: letteraIncipit: "Tra gli applausi d...
# ...

# %%
#uploading received letters
received = pd.read_csv('received.csv')
received
# Out:
#                                Expéditeur  \
# 0            Southwell  Robert  1635-1702
# 1     Lebesque  Marainville de  sec. XVII
# 2          Dati  Carlo Roberto  1619-1676
# 3              Chapelain  Jean  1595-1674
# 4         Chimentelli  Valerio  1620-1668
# ...                                   ...
# 1842          Rinaldini  Carlo  1615-1698
# 1843          Rinaldini  Carlo  1615-1698
# 1844          Rinaldini  Carlo  1615-1698
# 1845        Magalotti  Lorenzo  1637-1712
# 1846           Steensen  Niels  1638-1686
#
#                                                   Notes  \
# 0     Tipologia: letteraIncipit: "Per salis communi ...
# 1     Tipologia: letteraIncipit: "Ho ricevuto l'ordi...
# 2     Tipologia: letteraIncipit: "Carlo Dati manda a...
# 3     Tipologia: letteraIncipit: "Io vi scrivo di ra...
# 4     Tipologia: letteraIncipit: "Mi dispiace della ...
# ...                                                 ...
# 1842  Tipologia: letteraIncipit: "Ricevo questa matt...
# ...

# %%
#uploading sent letters
sent = pd.read_csv('sent.csv')
sent
# Out:
#                         Expéditeur  \
# 0     Viviani  Vincenzo  1622-1703
# 1     Viviani  Vincenzo  1622-1703
# 2     Viviani  Vincenzo  1622-1703
# 3     Viviani  Vincenzo  1622-1703
# 4     Viviani  Vincenzo  1622-1703
# ...                            ...
# 1016  Viviani  Vincenzo  1622-1703
# 1017  Viviani  Vincenzo  1622-1703
# 1018  Viviani  Vincenzo  1622-1703
# 1019  Viviani  Vincenzo  1622-1703
# 1020  Viviani  Vincenzo  1622-1703
#
#                                                   Notes  \
# 0     Tipologia: letteraIncipit: "Come posso non agg...
# 1     Tipologia: letteraIncipit: "Reputo a mio gran ...
# 2     Tipologia: letteraIncipit: "L'esser io per spa...
# 3     Tipologia: letteraIncipit: "Haverei necessità ...
# 4     Tipologia: letteraIncipit: "Qui tutto giorno c...
# ...                                                 ...
# 1016  Tipologia: letteraMinuta non firmata. Nel marg...
# 1017  Tipologia: letteraIncipit: "Per non mancare a ...
# ...

# %%
#for a specific query:(example)
#result = sent.loc[sent['Sujet'].str.contains('something')]
